# %%
import cv2, matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('./monky.jpg')
print(img)
# Out:
# [[[122 170 206]
#   [126 174 210]
#   [141 190 228]
#   ...,
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  [[126 171 208]
#   [125 170 207]
#   [136 185 223]
#   ...,
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  [[123 168 205]
#   [124 170 204]
#   [132 175 218]
#   ...,
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  ...,
#  [[ 26  38  72]
#   [ 20  32  68]
#   [ 13  26  64]
#   ...,
#   [ 60 115 184]
#   [ 56 111 180]
#   [ 52 107 176]]
#
#  [[ 27  37  71]
#   [ 20  30  64]
#   [ 15  27  61]
#   ...,
#   [ 62 116 181]
#   [ 60 114 179]
#   [ 50 104 169]]
#
#  [[ 21  33  67]
#   [ 16  28  62]
#   [ 14  26  62]
#   ...,
#   [ 62 114 180]
#   [ 60 112 178]
#   [ 46  98 164]]]

# %%
plt.imshow(img)

# %%
plt.show()
